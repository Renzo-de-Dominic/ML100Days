# %%
#選取單一元素
#選取某一列，某兩行的共兩個元素
#選取某行中，某個列範圍中共一個元素
#選取某個烈範圍與某些行範圍的元素，共8個

# %%
import numpy as np
import pandas as pd

# %%
df=pd.DataFrame(np.random.randn(6,3),columns=['col1','col2','col3'])
df
# Out:
#        col1      col2      col3
# 0  0.109091  0.778939  1.730810
# 1 -1.708546 -0.059290 -0.115375
# 2 -2.107081  1.541960  0.441072
# 3  0.228873  0.876530 -0.518124
# 4  1.279752 -0.191709  0.372371
# 5  0.185585 -0.874017 -0.221377

# %%
df[0:3]
# Out:
#        col1      col2      col3
# 0  0.109091  0.778939  1.730810
# 1 -1.708546 -0.059290 -0.115375
# 2 -2.107081  1.541960  0.441072

# %%
n=0
while n<4:
    print(df[(2*n+1):(2*n+2)])
    n+=1
# Out:
#        col1     col2      col3
# 1 -1.708546 -0.05929 -0.115375
#        col1     col2      col3
# 3  0.228873  0.87653 -0.518124
#        col1      col2      col3
# 5  0.185585 -0.874017 -0.221377
# Empty DataFrame
# Columns: [col1, col2, col3]
# Index: []

# %%
df[['col2', 'col3']]
# Out:
#        col2      col3
# 0  0.778939  1.730810
# 1 -0.059290 -0.115375
# 2  1.541960  0.441072
# 3  0.876530 -0.518124
# 4 -0.191709  0.372371
# 5 -0.874017 -0.221377

# %%
dt = pd.DataFrame(np.random.randint(10,40,60).reshape(-1,4))
dt
# Out:
#      0   1   2   3
# 0   16  30  30  20
# 1   38  35  34  16
# 2   39  24  22  20
# 3   38  29  19  38
# 4   22  38  15  29
# 5   30  32  39  20
# 6   27  34  29  37
# 7   18  17  17  39
# 8   17  38  13  23
# 9   24  29  29  22
# 10  10  11  15  33
# 11  29  27  29  10
# 12  27  35  34  16
# 13  25  27  27  18
# 14  39  32  22  32

# %%
dt[dt[[0]]>20][[0]]
# Out:
#        0
# 0    NaN
# 1   38.0
# 2   39.0
# 3   38.0
# 4   22.0
# 5   30.0
# 6   27.0
# 7    NaN
# 8    NaN
# 9   24.0
# 10   NaN
# 11  29.0
# 12  27.0
# 13  25.0
# 14  39.0

# %%
dt[dt>50][[0,1]]
# Out:
#      0   1
# 0  NaN NaN
# 1  NaN NaN
# 2  NaN NaN
# 3  NaN NaN
# 4  NaN NaN
# 5  NaN NaN
# 6  NaN NaN
# 7  NaN NaN
# 8  NaN NaN
# 9  NaN NaN
# 10 NaN NaN
# 11 NaN NaN
# 12 NaN NaN
# 13 NaN NaN
# 14 NaN NaN

# %%
print(dt[dt[[0]]<30][[0]])
print(dt[dt[[1]]>30][[1]])
# Out:
#        0
# 0   16.0
# 1    NaN
# 2    NaN
# 3    NaN
# 4   22.0
# 5    NaN
# 6   27.0
# 7   18.0
# 8   17.0
# 9   24.0
# 10  10.0
# 11  29.0
# 12  27.0
# 13  25.0
# 14   NaN
#        1
# 0    NaN
# 1   35.0
# 2    NaN
# 3    NaN
# 4   38.0
# 5   32.0
# 6   34.0
# 7    NaN
# 8   38.0
# 9    NaN
# 10   NaN
# 11   NaN
# 12  35.0
# 13   NaN
# 14  32.0

# %%
print(dt[dt.sum(axis=1)>100])
# Out:
#      0   1   2   3
# 1   38  35  34  16
# 2   39  24  22  20
# 3   38  29  19  38
# 4   22  38  15  29
# 5   30  32  39  20
# 6   27  34  29  37
# 9   24  29  29  22
# 12  27  35  34  16
# 14  39  32  22  32

# %%
#讀取 STOCK_DAY_0050_202009.csv 串聯 STOCK_DAY_0050_202010.csv
import csv
xfile=pd.read_csv('STOCK_DAY_0050_202010.csv')
xfile
# Out:
#          date    open    high     low   close

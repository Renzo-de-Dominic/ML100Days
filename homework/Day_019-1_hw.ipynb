# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#畫出完整的 cos 圖形
x=np.arange(-7,7,0.1)
y=np.cos(x)
plt.plot(x,y)

# %%
#2.    給定散點圖顏色
n=512
a = np.random.normal(0,1,n)
b = np.random.normal(0,1,n)
plt.scatter(a,b,edgecolors='green',alpha=0.4,s=70)
